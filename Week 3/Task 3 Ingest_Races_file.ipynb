# %% [markdown]
# ### Ingest races.csv file

# %% [markdown]
# ##### Step 1 - Read the CSV file using the spark dataframe reader API

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
races_schema = StructType(fields=[StructField("raceId", IntegerType(), False),
                                  StructField("year", IntegerType(), True),
                                  StructField("round", IntegerType(), True),
                                  StructField("circuitId", IntegerType(), True),
                                  StructField("name", StringType(), True),
                                  StructField("date", DateType(), True),
                                  StructField("time", StringType(), True),
                                  StructField("url", StringType(), True) 
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
races_df = spark.read \
.option("header", True) \
.schema(races_schema) \
.csv("/mnt/fformula1dl/raw/races.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### Step 2 - Add ingestion date and race_timestamp to the dataframe

# %%
from pyspark.sql.functions import current_timestamp, to_timestamp, concat, col, lit
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
races_with_timestamp_df = races_df.withColumn("ingestion_date", current_timestamp()) \
                                  .withColumn("race_timestamp", to_timestamp(concat(col('date'), lit(' '), col('time')), 'yyyy-MM-dd HH:mm:ss'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### Step 3 - Select only the columns required & rename as required

# %%
races_selected_df = races_with_timestamp_df.select(col('raceId').alias('race_id'), col('year').alias('race_year'), 
                                                   col('round'), col('circuitId').alias('circuit_id'),col('name'), col('ingestion_date'), col('race_timestamp'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### Write the output to processed container in parquet format

# %%
races_selected_df.write.mode('overwrite').partitionBy('race_year').parquet('/mnt/fformula1dl/processed/races')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs
ls /mnt/fformula1dl/processed/races
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/fformula1dl/processed/races/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1663277624000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1950/</td><td>race_year=1950/</td><td>0</td><td>1663277510000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1951/</td><td>race_year=1951/</td><td>0</td><td>1663277512000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1952/</td><td>race_year=1952/</td><td>0</td><td>1663277513000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1953/</td><td>race_year=1953/</td><td>0</td><td>1663277515000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1954/</td><td>race_year=1954/</td><td>0</td><td>1663277516000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1955/</td><td>race_year=1955/</td><td>0</td><td>1663277518000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1956/</td><td>race_year=1956/</td><td>0</td><td>1663277519000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1957/</td><td>race_year=1957/</td><td>0</td><td>1663277521000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1958/</td><td>race_year=1958/</td><td>0</td><td>1663277522000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1959/</td><td>race_year=1959/</td><td>0</td><td>1663277524000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1960/</td><td>race_year=1960/</td><td>0</td><td>1663277525000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1961/</td><td>race_year=1961/</td><td>0</td><td>1663277527000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1962/</td><td>race_year=1962/</td><td>0</td><td>1663277529000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1963/</td><td>race_year=1963/</td><td>0</td><td>1663277530000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1964/</td><td>race_year=1964/</td><td>0</td><td>1663277532000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1965/</td><td>race_year=1965/</td><td>0</td><td>1663277533000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1966/</td><td>race_year=1966/</td><td>0</td><td>1663277535000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1967/</td><td>race_year=1967/</td><td>0</td><td>1663277536000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1968/</td><td>race_year=1968/</td><td>0</td><td>1663277538000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1969/</td><td>race_year=1969/</td><td>0</td><td>1663277539000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1970/</td><td>race_year=1970/</td><td>0</td><td>1663277541000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1971/</td><td>race_year=1971/</td><td>0</td><td>1663277542000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1972/</td><td>race_year=1972/</td><td>0</td><td>1663277544000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1973/</td><td>race_year=1973/</td><td>0</td><td>1663277545000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1974/</td><td>race_year=1974/</td><td>0</td><td>1663277547000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1975/</td><td>race_year=1975/</td><td>0</td><td>1663277548000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1976/</td><td>race_year=1976/</td><td>0</td><td>1663277550000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1977/</td><td>race_year=1977/</td><td>0</td><td>1663277551000</td></tr><tr><td>dbfs:/mnt/fformula1dl/processed/races/race_year=1978/</td><td>race_year=1978/</td><td>0</td><td>1663277553000</td></tr><tr>< ...
